# %% [markdown]
# # 호텔 예약 취소 예측

# %% [markdown]
# ## 서론

# %% [markdown]
# ### 분석 배경

# %% [markdown]
# 호텔 방을 예약하기에 가장 좋은 시기가 언제인지 궁금한 적이 있습니까?
# 아니면 최고의 일일 요금을 얻기 위해 최적의 체류 기간?
# 호텔이 불균형 적으로 많은 수의 특별 요청을 받을 가능성이 있는지 여부를 예측하려면 어떻게 해야 합니까?
#
# 이 호텔 예약 데이터 세트는 이러한 질문을 탐색하는 데 도움이 됩니다!
#
# 데이터에서 다루는 주제 및 질문 :
#
# 손님은 어디에서 오나요?<br>
# 객실당 1 박 요금은 얼마입니까?<br>
# 1 박 가격은 연중 어떻게 달라 집니까?<br>
# 가장 바쁜 달은 어느 것입니까?<br>
# 사람들이 호텔에 얼마나 오래 있습니까?<br>
# 시장 세그먼트 별 예약<br>
# 몇 번의 예약이 취소 되었습니까?<br>
# 어느 달에 가장 많은 취소 횟수가 있습니까?<br>
# 취소를 예측하는 데 가장 중요한 기능은 무엇입니까?

# %% [markdown]
# ### 분석 목표

# %% [markdown]
# 호텔 취소 예측

# %% [markdown]
# ### 변수 설명

# %% [markdown]
#  이름 | 형식 | 설명
# :---:|:---:|:---
# 호텔 |  | 호텔 구분,<br> H1 = 리조트 호텔,<br> H2 = 시티 호텔
# is_canceled |  | 예약이 취소되었는지 여부를 나타내는 값,<br> 0:숙박,<br> 1:취소
# lead_time |  | 예약 시작 날짜와 도착 날짜 사이에 경과 된 일수
# arrival_date_year |  | 도착 연도
# arrival_date_month |  | 도착 월
# arrival_date_week_number |  | 도착한 주
# arrival_date_day_of_month |  | 도착한 일자
# stays_in_weekend_nights |  | 손님이 호텔에 숙박하거나 예약한 주말 밤(토요일 또는 일요일)의 수
# stays_in_week_nights |  | 손님이 호텔에 숙박하거나 예약한 주중 밤(월요일 ~ 금요일)의 수
# adults |  | 성인의 수
# children |  | 어린이의 수
# babies |  | 아기의 수
# meal |  | 예약 된 식사 유형,<br> Undefined/SC : 식사 패키지 없음,<br> BB : 침대&아침 식사,<br> HB : 하프 보드 (아침 식사와 다른 식사 – 보통 저녁),<br> FB : 풀 보드 (아침, 점심 및 저녁)
# country |  | ISO에서 규정한 ISO 3166-1 국가코드 표준 형식으로 표기
# market_segment |  | TA : 여행사,<br> TO : 관광업자
# distribution_channel |  | 예약 배포 채널,<br> TA : 여행사,<br> TO : 관광업자
# is_repeated_guest |  | 예약 이름이 반복 손님의 이름인지 (1) 아닌지 (0)를 나타내는 값
# previous_cancellations |  | 현재 예약 이전에 고객이 취소 한 이전 예약 수
# previous_bookings_not_canceled |  | 현재 예약 이전에 고객이 취소하지 않은 이전 예약 수
# reserved_room_type |  | 예약된 객실 유형의 코드
# assigned_room_type |  | 예약에 지정된 객실 유형 코드. 호텔 운영상의 이유(예 : 초과 예약) 또는 고객 요청으로 인해 <br>지정된 객실 유형이 예약 된 객실 유형과 다를 수 있음
# booking_changes |  | PMS에 예약을 입력 한 순간부터 체크인 또는 취소까지 예약에 대한 변경 / 수정 횟수
# deposit_type |  | 고객이 예약을 보장하기 위해 보증금을 지불했는지 표시,<br> No Deposit : 보증금 없음 ,<br> Non Refund : 총 체류 기간에 대한 가치 == 보증금, 환불 불가,<br> Refundable : 총 체류 기간에 대한 가치 > 보증금 , 환불 가능
# agent |  | 예약을 하거나 예약 요금을 지불한 회사
# company |  | 예약 또는 지불 책임이 있는 회사/법인
# days_in_waiting_list |  | 예약이 고객에게 확인되기 전 대기 목록에 있었던 일 수
# customer_type |  | Transient : 그외 채널로 호텔 객실을 예약하는 개별 고객,<br> Contract : 항공사 크루나 장기 투숙고객 등,<br> Transient-Party : 써드파티 채널을 통해 호텔 객실을 예약하는 개별 고객,<br> Group : 보통 10개 이상의 객실을 한꺼번에 이용하는 고객
# adr |  | 모든 숙박 거래의 총계를 총 숙박 일수로 나누어 정의한 평균 일일 요금
# required_car_parking_spaces |  | 고객이 요구 한 주차 공간 수
# total_of_special_requests |  | 고객이 요청한 특별 요구사항 수 (예 : 트윈 베드 또는 고층)
# reservation_status |  | 다음 세 가지 범주 중 하나를 가정하여 예약 마지막 상태,<br> Canceled : 예약 취소,<br> Check-Out : 고객이 체크인했지만 이미 출발함,<br> No-Show : 고객은 체크인을 하지 않고 호텔에 그 이유를 알림
# reservation_status_date |  | 마지막 상태가 설정된 날짜,<br> 이 변수는 ReservationStatus와 함께 사용하여 예약이 언제 취소되었는지 또는 고객이 호텔을 체크 아웃했는지를 알 수 있음

# %% [markdown]
# 출처 : [Hotel booking demand](https://www.kaggle.com/jessemostipak/hotel-booking-demand)

# %% [markdown]
# ## 라이브러리 로드

# %% [markdown]
# #### 필요한 라이브러리 불러오기

# %%
import pandas as pd # 데이터 프레임
import numpy as np # 계산
import re # 정규표현식

import warnings
warnings.filterwarnings('ignore') # warning 메시지 제거

import seaborn as sns # 시각화
import graphviz # 시각화
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import f1_score,confusion_matrix
# %matplotlib inline

# %% [markdown]
# #### 시각화를 위한 한글 폰트 설정하기

# %%
import matplotlib.pyplot as plt

# 한글 폰트 지정
plt.rc('font', family='AppleGothic') # 맥
# plt.rc('font', family='Malgun Gothic') # 윈도우

# 마이너스 값 깨지는 현상 해결
plt.rc('axes', unicode_minus=False)

# 레티나 디스플레이 설정
from IPython.display import set_matplotlib_formats

set_matplotlib_formats('retina')

# %% [markdown]
# #### 작업 경로 지정

# %%
import os # wd 변경

# os로 작업 경로 지정
# os.chdir('D:/5 Project/GitHub/CollaborationWork/jyeon94/Learning_Spoons_Second_Project/data/')
os.chdir('/Users/jungdayoung/Documents/GitHub/Learning_Spoons_Third_Project/data/')

# %% [markdown]
# ## 데이터셋 가져오기

# %%
df = pd.read_csv('../data/hotel_bookings.csv')
df.shape
# Out:
# (119390, 32)

# %%
# 컬럼이 모두 보이도록 설정합니다.

pd.options.display.max_columns = 32

# %%
# 미리보기를 합니다.

df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# 1                        0                     0       2       0.0       0
# 2                        0                     1       1       0.0       0
# 3                        0                     1       1       0.0       0
# 4                        0                     2       2       0.0       0
#
#   meal country market_segment distribution_channel  is_repeated_guest  \
# 0   BB     PRT         Direct               Direct                  0
# 1   BB     PRT         Direct               Direct                  0
# 2   BB     GBR         Direct               Direct                  0
# 3   BB     GBR      Corporate            Corporate                  0
# 4   BB     GBR      Online TA                TA/TO                  0
#
#    previous_cancellations  previous_bookings_not_canceled reserved_room_type  \
# 0                       0                               0                  C
# 1                       0                               0                  C
# 2                       0                               0                  A
# 3                       0                               0                  A
# 4                       0                               0                  A
#
#   assigned_room_type  booking_changes deposit_type  agent  company  \
# 0                  C                3   No Deposit    NaN      NaN
# 1                  C                4   No Deposit    NaN      NaN
# 2                  C                0   No Deposit    NaN      NaN
# 3                  A                0   No Deposit  304.0      NaN
# 4                  A                0   No Deposit  240.0      NaN
#
#    days_in_waiting_list customer_type   adr  required_car_parking_spaces  \
# 0                     0     Transient   0.0                            0
# 1                     0     Transient   0.0                            0
# 2                     0     Transient  75.0                            0
# 3                     0     Transient  75.0                            0
# 4                     0     Transient  98.0                            0
#
#    total_of_special_requests reservation_status reservation_status_date
# 0                          0          Check-Out              2015-07-01
# 1                          0          Check-Out              2015-07-01
# 2                          0          Check-Out              2015-07-02
# 3                          0          Check-Out              2015-07-02
# 4                          1          Check-Out              2015-07-03

# %% [markdown]
# ## EDA

# %% [markdown]
# ### pandas-profiling

# %%
# pandas_profiling 을 통해 ProfileReport 로 간단한 eda 리포트를 만들어 봅니다.

# from pandas_profiling import ProfileReport

# Profile = ProfileReport(df)
# Profile.to_file(output_file = 'hotel_cancelations.html')

# %% [markdown]
# ### histogram

# %%
h = df.hist(figsize=(15, 15))
# Out:
# findfont: Font family ['AppleGothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['AppleGothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ### 데이터 전처리

# %% [markdown]
# #### 결측치 채우기

# %%
# 결측치 확인
df.isnull().sum().sort_values(ascending=False).head()
# Out:
# company      112593
# agent         16340
# country         488
# children          4
# lead_time         0
# dtype: int64

# %%
# 'country' 값의 결측치를 "None" 으로 채우기
df['country'] = df['country'].fillna("None")

# %%
# 'company'의 결측치가 약 94.3%로 해당 열 삭제
df = df.drop(['company'], axis=1)

# %%
# 'agent'의 결측치를 0으로 대체
df['agent'] = df['agent'].fillna(0)

# %%
# 'children'의 결측치 4개를 0으로 대체
df['children'] = df['children'].fillna(0)

# %% [markdown]
# #### 데이터 타입 변경

# %%
# 'arrival_date_month'의 데이터 타입을 숫자로 변경한 컬럼 추가
import calendar
calendar_month = {v:k for k,v in enumerate(calendar.month_abbr)}
del calendar_month['']
 
def month_number(data):
    for keys,values in calendar_month.items():
        data.loc[data['arrival_date_month'].str.contains(keys),'arrival_date_month_num'] = values
    data['arrival_date_month_num'] = data['arrival_date_month_num'].astype('int')
    return data[['arrival_date_month','arrival_date_month_num']]

# %%
month_number(df)
# Out:
#        arrival_date_month  arrival_date_month_num
# 0                    July                       7
# 1                    July                       7
# 2                    July                       7
# 3                    July                       7
# 4                    July                       7
# ...                   ...                     ...
# 119385             August                       8
# 119386             August                       8
# 119387             August                       8
# 119388             August                       8
# 119389             August                       8
#
# [119390 rows x 2 columns]

# %% [markdown]
# ### 데이터 시각화

# %% [markdown]
# #### 연도별, 호텔별 예약 취소율

# %%
# Hotel을 나누기 위해 원핫인코딩하기
# data_ohe = pd.get_dummies(df['hotel'])
# data_ohe

# %%
# 원핫인코딩한 데이터와 기존 데이터 합치기
# df = pd.merge(data_ohe, df, how='left', left_index=True, right_index=True)
# df.head()

# %%
df_s = df.groupby(['hotel', 'arrival_date_month'])['is_canceled'].value_counts().unstack().reset_index()
df_s
# Out:
# is_canceled         hotel arrival_date_month     0     1
# 0              City Hotel              April  4015  3465
# 1              City Hotel             August  5381  3602
# 2              City Hotel           December  2392  1740
# 3              City Hotel           February  3064  1901
# 4              City Hotel            January  2254  1482
# 5              City Hotel               July  4782  3306
# 6              City Hotel               June  4366  3528
# 7              City Hotel              March  4072  2386
# 8              City Hotel                May  4579  3653
# 9              City Hotel           November  2696  1661
# 10             City Hotel            October  4337  3268
# 11             City Hotel          September  4290  3110
# 12           Resort Hotel              April  2550  1059
# 13           Resort Hotel             August  3257  1637
# 14           Resort Hotel           December  2017   631
# 15           Resort Hotel           February  2308   795
# 16           Resort Hotel            January  1868   325
# 17           Resort Hotel               July  3137  1436
# 18           Resort Hotel               June  2038  1007
# 19           Resort Hotel              March  2573   763
# 20           Resort Hotel                May  2535  1024
# 21           Resort Hotel           November  1976   461
# 22           Resort Hotel            October  2577   978
# 23           Resort Hotel          September  2102  1006

# %%
df_ss = df.groupby(['hotel', 'arrival_date_month'])['is_canceled'].count().reset_index()
df_ss
# Out:
#            hotel arrival_date_month  is_canceled
# 0     City Hotel              April         7480
# 1     City Hotel             August         8983
# 2     City Hotel           December         4132
# 3     City Hotel           February         4965
# 4     City Hotel            January         3736
# 5     City Hotel               July         8088
# 6     City Hotel               June         7894
# 7     City Hotel              March         6458
# 8     City Hotel                May         8232
# 9     City Hotel           November         4357
# 10    City Hotel            October         7605
# 11    City Hotel          September         7400
# 12  Resort Hotel              April         3609
# 13  Resort Hotel             August         4894
# 14  Resort Hotel           December         2648
# 15  Resort Hotel           February         3103
# 16  Resort Hotel            January         2193
# 17  Resort Hotel               July         4573
# 18  Resort Hotel               June         3045
# 19  Resort Hotel              March         3336
# 20  Resort Hotel                May         3559
# 21  Resort Hotel           November         2437
# 22  Resort Hotel            October         3555
# 23  Resort Hotel          September         3108

# %%
df_sss = pd.merge(df_s, df_ss, on=['hotel', 'arrival_date_month'])
df_sss
# Out:
#            hotel arrival_date_month     0     1  is_canceled
# 0     City Hotel              April  4015  3465         7480
# 1     City Hotel             August  5381  3602         8983
# 2     City Hotel           December  2392  1740         4132
# 3     City Hotel           February  3064  1901         4965
# 4     City Hotel            January  2254  1482         3736
# 5     City Hotel               July  4782  3306         8088
# 6     City Hotel               June  4366  3528         7894
# 7     City Hotel              March  4072  2386         6458
# 8     City Hotel                May  4579  3653         8232
# 9     City Hotel           November  2696  1661         4357
# 10    City Hotel            October  4337  3268         7605
# 11    City Hotel          September  4290  3110         7400
# 12  Resort Hotel              April  2550  1059         3609
# 13  Resort Hotel             August  3257  1637         4894
# 14  Resort Hotel           December  2017   631         2648
# 15  Resort Hotel           February  2308   795         3103
# 16  Resort Hotel            January  1868   325         2193
# 17  Resort Hotel               July  3137  1436         4573
# 18  Resort Hotel               June  2038  1007         3045
# 19  Resort Hotel              March  2573   763         3336
# 20  Resort Hotel                May  2535  1024         3559
# 21  Resort Hotel           November  1976   461         2437
# 22  Resort Hotel            October  2577   978         3555
# 23  Resort Hotel          September  2102  1006         3108

# %%
df_sss['숙박율'] = df_sss[0] / df_sss['is_canceled']
df_sss['취소율'] = df_sss[1] / df_sss['is_canceled']
df_sss
# Out:
#            hotel arrival_date_month     0     1  is_canceled       숙박율  \
# 0     City Hotel              April  4015  3465         7480  0.536765
# 1     City Hotel             August  5381  3602         8983  0.599020
# 2     City Hotel           December  2392  1740         4132  0.578896
# 3     City Hotel           February  3064  1901         4965  0.617120
# 4     City Hotel            January  2254  1482         3736  0.603319
# 5     City Hotel               July  4782  3306         8088  0.591246
# 6     City Hotel               June  4366  3528         7894  0.553078
# 7     City Hotel              March  4072  2386         6458  0.630536
# 8     City Hotel                May  4579  3653         8232  0.556244
# 9     City Hotel           November  2696  1661         4357  0.618774
# 10    City Hotel            October  4337  3268         7605  0.570283
# 11    City Hotel          September  4290  3110         7400  0.579730
# 12  Resort Hotel              April  2550  1059         3609  0.706567
# 13  Resort Hotel             August  3257  1637         4894  0.665509
# 14  Resort Hotel           December  2017   631         2648  0.761707
# 15  Resort Hotel           February  2308   795         3103  0.743796
# 16  Resort Hotel            January  1868   325         2193  0.851801
# 17  Resort Hotel               July  3137  1436         4573  0.685983
# 18  Resort Hotel               June  2038  1007         3045  0.669294
# 19  Resort Hotel              March  2573   763         3336  0.771283
# 20  Resort Hotel                May  2535  1024         3559  0.712279
# 21  Resort Hotel           November  1976   461         2437  0.810833
# 22  Resort Hotel            October  2577   978         3555  0.724895
# 23  Resort Hotel          September  2102  1006         3108  0.676319
#
#          취소율
# 0   0.463235
# 1   0.400980
# 2   0.421104
# 3   0.382880
# 4   0.396681
# 5   0.408754
# 6   0.446922
# 7   0.369464
# 8   0.443756
# 9   0.381226
# 10  0.429717
# 11  0.420270
# 12  0.293433
# 13  0.334491
# 14  0.238293
# 15  0.256204
# 16  0.148199
# 17  0.314017
# 18  0.330706
# 19  0.228717
# 20  0.287721
# 21  0.189167
# 22  0.275105
# 23  0.323681

# %%
plt.figure(figsize=(15,4))
sns.barplot(data=df_sss, x='arrival_date_month', y='취소율', hue='hotel', ci=None)

# %% [markdown]
# #### 월별  Lead time과 cancellation

# %%
can = df.loc[df['is_canceled'] == 1, ['hotel', 'lead_time', 'reservation_status', 'reservation_status_date']]
can
# Out:
#                hotel  lead_time reservation_status reservation_status_date
# 8       Resort Hotel         85           Canceled              2015-05-06
# 9       Resort Hotel         75           Canceled              2015-04-22
# 10      Resort Hotel         23           Canceled              2015-06-23
# 27      Resort Hotel         60           Canceled              2015-05-11
# 32      Resort Hotel         96           Canceled              2015-05-29
# ...              ...        ...                ...                     ...
# 110280    City Hotel        132           Canceled              2017-04-25
# 111355    City Hotel          4           Canceled              2017-06-05
# 111924    City Hotel          7           Canceled              2017-05-31
# 111925    City Hotel          6            No-Show              2017-07-17
# 117295    City Hotel          0            No-Show              2017-08-02
#
# [44224 rows x 4 columns]

# %%
can['연월'] = can['reservation_status_date'].str.split('-').str.get(0) + '-' + can['reservation_status_date'].str.split('-').str.get(1)
can
# Out:
#                hotel  lead_time reservation_status reservation_status_date  \
# 8       Resort Hotel         85           Canceled              2015-05-06
# 9       Resort Hotel         75           Canceled              2015-04-22
# 10      Resort Hotel         23           Canceled              2015-06-23
# 27      Resort Hotel         60           Canceled              2015-05-11
# 32      Resort Hotel         96           Canceled              2015-05-29
# ...              ...        ...                ...                     ...
# 110280    City Hotel        132           Canceled              2017-04-25
# 111355    City Hotel          4           Canceled              2017-06-05
# 111924    City Hotel          7           Canceled              2017-05-31
# 111925    City Hotel          6            No-Show              2017-07-17
# 117295    City Hotel          0            No-Show              2017-08-02
#
#              연월
# 8       2015-05
# 9       2015-04
# 10      2015-06
# 27      2015-05
# 32      2015-05
# ...         ...
# 110280  2017-04
# 111355  2017-06
# 111924  2017-05
# 111925  2017-07
# 117295  2017-08
#
# [44224 rows x 5 columns]

# %%
can_date = can.groupby(['연월'])['reservation_status_date'].count()
can_date = pd.DataFrame(can_date).reset_index()
can_date
# Out:
#          연월  reservation_status_date
# 0   2014-10                      180
# 1   2014-11                        1
# 2   2015-01                      948
# 3   2015-02                       44
# 4   2015-03                       85
# 5   2015-04                      151
# 6   2015-05                      275
# 7   2015-06                      666
# 8   2015-07                     2294
# 9   2015-08                     1023
# 10  2015-09                     1031
# 11  2015-10                     2438
# 12  2015-11                     1090
# 13  2015-12                     1422
# 14  2016-01                     2497
# 15  2016-02                     2161
# 16  2016-03                     2125
# 17  2016-04                     1867
# 18  2016-05                     1430
# 19  2016-06                     1384
# 20  2016-07                     1373
# 21  2016-08                     1345
# 22  2016-09                     1645
# 23  2016-10                     1527
# 24  2016-11                     1969
# 25  2016-12                     2105
# 26  2017-01                     2616
# 27  2017-02                     2153
# 28  2017-03                     1610
# 29  2017-04                     1452
# 30  2017-05                     1433
# 31  2017-06                      862
# 32  2017-07                      702
# 33  2017-08                      320

# %%
plt.figure(figsize=(15, 4))
plt.xticks(rotation=90)
sns.lineplot(data=can, x='연월', y='lead_time', ci=None)
sns.lineplot(data=can_date, x='연월', y='reservation_status_date', ci=None)

# %% [markdown]
# #### 이전에 취소한 고객에 의한 취소

# %%
h = df.loc[(df['previous_cancellations']>0)&(df['is_canceled']==1),'previous_cancellations'].value_counts().sort_index()
plt.figure(figsize=(15,5))
sns.lineplot(data=h)

# %% [markdown]
# #### deposit type과 customer type에 따른 취소

# %%
import calendar
calendar_month = {v:k for k,v in enumerate(calendar.month_abbr)}
del calendar_month['']
 
def month_number(data):
    for keys,values in calendar_month.items():
        data.loc[data['arrival_date_month'].str.contains(keys),'arrival_date_month_num'] = values
    df['arrival_date_month_num'] = df['arrival_date_month_num'].astype('int')
    return df[['arrival_date_month','arrival_date_month_num']]

# %%
df_no_deposit = df[df['deposit_type']=='No Deposit']
df_non_refund = df[df['deposit_type'] =='Non Refund']
df_refundable = df[df['deposit_type']=='Refundable']

# %%
figure, (ax1,ax2,ax3) = plt.subplots(nrows=1,ncols=3)
figure.set_size_inches(15,5)
sns.countplot(data=df_no_deposit,x='is_canceled',hue='deposit_type',ax=ax1,palette="Blues_r")
sns.countplot(data=df_non_refund,x='is_canceled',hue='deposit_type',ax=ax2,palette="GnBu")
sns.countplot(data=df_refundable,x='is_canceled',hue='deposit_type',ax=ax3,palette="Greens")

# %%
df_transient = df[df['customer_type']=='Transient']
df_transient_party = df[df['customer_type'] =='Transient-Party']
df_contract = df[df['customer_type']=='Contract']
df_group = df[df['customer_type']=='Group']

# %%
figure, (ax1,ax2,ax3,ax4) = plt.subplots(nrows=1,ncols=4)
figure.set_size_inches(15,5)
sns.countplot(data=df_transient,x='is_canceled',hue='customer_type',ax=ax1,palette="Blues")
sns.countplot(data=df_transient_party,x='is_canceled',hue='customer_type',ax=ax2,palette="GnBu")
sns.countplot(data=df_contract,x='is_canceled',hue='customer_type',ax=ax3,palette="Greens")
sns.countplot(data=df_group,x='is_canceled',hue='customer_type',ax=ax4,palette="YlGnBu")

# %% [markdown]
# #### 컬럼 상세 보기

# %%
df.groupby(['deposit_type'])['adr'].mean()
# Out:
# deposit_type
# No Deposit    103.525067
# Non Refund     89.964017
# Refundable     76.209753
# Name: adr, dtype: float64

# %%
df.groupby(['is_canceled', 'deposit_type'])['adr'].mean()
# Out:
# is_canceled  deposit_type
# 0            No Deposit      100.068209
#              Non Refund       77.578817
#              Refundable       68.635159
# 1            No Deposit      112.250099
#              Non Refund       90.043486
#              Refundable      102.720833
# Name: adr, dtype: float64

# %%
df.groupby(['is_canceled', 'market_segment'])['adr'].count()
# Out:
# is_canceled  market_segment
# 0            Aviation            185
#              Complementary       646
#              Corporate          4303
#              Direct            10672
#              Groups             7714
#              Offline TA/TO     15908
#              Online TA         35738
# 1            Aviation             52
#              Complementary        97
#              Corporate           992
#              Direct             1934
#              Groups            12097
#              Offline TA/TO      8311
#              Online TA         20739
#              Undefined             2
# Name: adr, dtype: int64

# %%
df.groupby(['is_canceled', 'distribution_channel'])['adr'].count()
# Out:
# is_canceled  distribution_channel
# 0            Corporate                5203
#              Direct                  12088
#              GDS                       156
#              TA/TO                   57718
#              Undefined                   1
# 1            Corporate                1474
#              Direct                   2557
#              GDS                        37
#              TA/TO                   40152
#              Undefined                   4
# Name: adr, dtype: int64

# %%
df.groupby(['is_canceled', 'reserved_room_type'])['adr'].count()
# Out:
# is_canceled  reserved_room_type
# 0            A                     52364
#              B                       750
#              C                       624
#              D                     13099
#              E                      4621
#              F                      2017
#              G                      1331
#              H                       356
#              L                         4
# 1            A                     33630
#              B                       368
#              C                       308
#              D                      6102
#              E                      1914
#              F                       880
#              G                       763
#              H                       245
#              L                         2
#              P                        12
# Name: adr, dtype: int64

# %% [markdown]
# ### 상관 분석

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# 1                        0                     0       2       0.0       0
# 2                        0                     1       1       0.0       0
# 3                        0                     1       1       0.0       0
# 4                        0                     2       2       0.0       0
#
#   meal country market_segment distribution_channel  is_repeated_guest  \
# 0   BB     PRT         Direct               Direct                  0
# 1   BB     PRT         Direct               Direct                  0
# 2   BB     GBR         Direct               Direct                  0
# 3   BB     GBR      Corporate            Corporate                  0
# 4   BB     GBR      Online TA                TA/TO                  0
#
#    previous_cancellations  previous_bookings_not_canceled reserved_room_type  \
# 0                       0                               0                  C
# 1                       0                               0                  C
# 2                       0                               0                  A
# 3                       0                               0                  A
# 4                       0                               0                  A
#
#   assigned_room_type  booking_changes deposit_type  agent  \
# 0                  C                3   No Deposit    0.0
# 1                  C                4   No Deposit    0.0
# 2                  C                0   No Deposit    0.0
# 3                  A                0   No Deposit  304.0
# 4                  A                0   No Deposit  240.0
#
#    days_in_waiting_list customer_type   adr  required_car_parking_spaces  \
# 0                     0     Transient   0.0                            0
# 1                     0     Transient   0.0                            0
# 2                     0     Transient  75.0                            0
# 3                     0     Transient  75.0                            0
# 4                     0     Transient  98.0                            0
#
#    total_of_special_requests reservation_status reservation_status_date  \
# 0                          0          Check-Out              2015-07-01
# 1                          0          Check-Out              2015-07-01
# 2                          0          Check-Out              2015-07-02
# 3                          0          Check-Out              2015-07-02
# 4                          1          Check-Out              2015-07-03
#
#    arrival_date_month_num
# 0                       7
# 1                       7
# 2                       7
# 3                       7
# 4                       7

# %%
# 호텔 컬럼을 수치형으로 변환
df['hotel_encode'] = df['hotel'].apply(lambda x: 0 if x == 'Resort Hotel' else 1)
df['hotel_encode'].value_counts()
# Out:
# 1    79330
# 0    40060
# Name: hotel_encode, dtype: int64

# %%
df.corr()
# Out:
#                                 is_canceled  lead_time  arrival_date_year  \
# is_canceled                        1.000000   0.293123           0.016660
# lead_time                          0.293123   1.000000           0.040142
# arrival_date_year                  0.016660   0.040142           1.000000
# arrival_date_week_number           0.008148   0.126871          -0.540561
# arrival_date_day_of_month         -0.006130   0.002268          -0.000221
# stays_in_weekend_nights           -0.001791   0.085671           0.021497
# stays_in_week_nights               0.024765   0.165799           0.030883
# adults                             0.060017   0.119519           0.029635
# children                           0.005036  -0.037613           0.054636
# babies                            -0.032491  -0.020915          -0.013192
# is_repeated_guest                 -0.084793  -0.124410           0.010341
# previous_cancellations             0.110133   0.086042          -0.119822
# previous_bookings_not_canceled    -0.057358  -0.073548           0.029218
# booking_changes                   -0.144381   0.000149           0.030872
# agent                             -0.046529  -0.012640           0.056463
# days_in_waiting_list               0.054186   0.170084          -0.056497
# adr                                0.047557  -0.063077           0.197580
# required_car_parking_spaces       -0.195498  -0.116451          -0.013684
# total_of_special_requests         -0.234658  -0.095712           0.108531
# arrival_date_month_num             0.011022   0.131424          -0.527739
# hotel_encode                       0.136531   0.075381           0.035267
#
#                                 arrival_date_week_number  \
# is_canceled                                     0.008148
# lead_time                                       0.126871
# arrival_date_year                              -0.540561
# arrival_date_week_number                        1.000000
# arrival_date_day_of_month                       0.066809
# stays_in_weekend_nights                         0.018208
# stays_in_week_nights                            0.015558
# adults                                          0.025909
# children                                        0.005515
# babies                                          0.010395
# is_repeated_guest                              -0.030131
# previous_cancellations                          0.035501
# previous_bookings_not_canceled                 -0.020904
# booking_changes                                 0.005508
# agent                                          -0.018244
# days_in_waiting_list                            0.022933
# adr                                             0.075791
# required_car_parking_spaces                     0.001920
# total_of_special_requests                       0.026149
# arrival_date_month_num                          0.995105
# hotel_encode                                    0.001270
#
#                                 arrival_date_day_of_month  \
# is_canceled                                     -0.006130
# lead_time                                        0.002268
# arrival_date_year                               -0.000221
# arrival_date_week_number                         0.066809
# arrival_date_day_of_month                        1.000000
# stays_in_weekend_nights                         -0.016354
# stays_in_week_nights                            -0.028174
# adults                                          -0.001566
# children                                         0.014553
# babies                                          -0.000230
# is_repeated_guest                               -0.006145
# previous_cancellations                          -0.027011
# previous_bookings_not_canceled                  -0.000300
# booking_changes                                  0.010613
# agent                                            0.000202
# days_in_waiting_list                             0.022728
# adr                                              0.030245
# required_car_parking_spaces                      0.008683
# total_of_special_requests                        0.003062
# arrival_date_month_num                          -0.026063
# hotel_encode                                    -0.001862
#
#                                 stays_in_weekend_nights  stays_in_week_nights  \
# is_canceled                                   -0.001791              0.024765
# lead_time                                      0.085671              0.165799
# arrival_date_year                              0.021497              0.030883
# arrival_date_week_number                       0.018208              0.015558
# arrival_date_day_of_month                     -0.016354             -0.028174
# stays_in_weekend_nights                        1.000000              0.498969
# stays_in_week_nights                           0.498969              1.000000
# adults                                         0.091871              0.092976
# children                                       0.045794              0.044203
# babies                                         0.018483              0.020191
# is_repeated_guest                             -0.087239             -0.097245
# previous_cancellations                        -0.012775             -0.013992
# previous_bookings_not_canceled                -0.042715             -0.048743
# booking_changes                                0.063281              0.096209
# agent                                          0.161427              0.195135
# days_in_waiting_list                          -0.054151             -0.002020
# adr                                            0.049342              0.065237
# required_car_parking_spaces                   -0.018554             -0.024859
# total_of_special_requests                      0.072671              0.068192
# arrival_date_month_num                         0.018440              0.019212
# hotel_encode                                  -0.186596             -0.234020
#
#                                   adults  children    babies  \
# is_canceled                     0.060017  0.005036 -0.032491
# lead_time                       0.119519 -0.037613 -0.020915
# arrival_date_year               0.029635  0.054636 -0.013192
# arrival_date_week_number        0.025909  0.005515  0.010395
# arrival_date_day_of_month      -0.001566  0.014553 -0.000230
# stays_in_weekend_nights         0.091871  0.045794  0.018483
# stays_in_week_nights            0.092976  0.044203  0.020191
# adults                          1.000000  0.030440  0.018146
# children                        0.030440  1.000000  0.024030
# babies                          0.018146  0.024030  1.000000
# is_repeated_guest              -0.146426 -0.032858 -0.008943
# previous_cancellations         -0.006738 -0.024729 -0.007501
# previous_bookings_not_canceled -0.107983 -0.021072 -0.006550
# booking_changes                -0.051673  0.048952  0.083440
# agent                           0.024994  0.050581  0.030266
# days_in_waiting_list           -0.008283 -0.033271 -0.010621
# adr                             0.230641  0.324853  0.029186
# required_car_parking_spaces     0.014785  0.056255  0.037383
# total_of_special_requests       0.122884  0.081736  0.097889
# arrival_date_month_num          0.028534  0.005437  0.010172
# hotel_encode                   -0.013183 -0.044210 -0.043434
#
#                                 is_repeated_guest  previous_cancellations  \
# is_canceled                             -0.084793                0.110133
# lead_time                               -0.124410                0.086042
# arrival_date_year                        0.010341               -0.119822
# arrival_date_week_number                -0.030131                0.035501
# arrival_date_day_of_month               -0.006145               -0.027011
# stays_in_weekend_nights                 -0.087239               -0.012775
# stays_in_week_nights                    -0.097245               -0.013992
# adults                                  -0.146426               -0.006738
# children                                -0.032858               -0.024729
# babies                                  -0.008943               -0.007501
# is_repeated_guest                        1.000000                0.082293
# previous_cancellations                   0.082293                1.000000
# previous_bookings_not_canceled           0.418056                0.152728
# booking_changes                          0.012092               -0.026993
# agent                                   -0.052264               -0.018192
# days_in_waiting_list                    -0.022235                0.005929
# adr                                     -0.134314               -0.065646
# required_car_parking_spaces              0.077090               -0.018492
# total_of_special_requests                0.013050               -0.048384
# arrival_date_month_num                  -0.030729                0.037479
# hotel_encode                            -0.050421               -0.012292
#
#                                 previous_bookings_not_canceled  \
# is_canceled                                          -0.057358
# lead_time                                            -0.073548
# arrival_date_year                                     0.029218
# arrival_date_week_number                             -0.020904
# arrival_date_day_of_month                            -0.000300
# stays_in_weekend_nights                              -0.042715
# stays_in_week_nights                                 -0.048743
# adults                                               -0.107983
# children                                             -0.021072
# babies                                               -0.006550
# is_repeated_guest                                     0.418056
# previous_cancellations                                0.152728
# previous_bookings_not_canceled                        1.000000
# booking_changes                                       0.011608
# agent                                                -0.046296
# days_in_waiting_list                                 -0.009397
# adr                                                  -0.072144
# required_car_parking_spaces                           0.047653
# total_of_special_requests                             0.037824
# arrival_date_month_num                               -0.021640
# hotel_encode                                         -0.004441
#
#                                 booking_changes     agent  \
# is_canceled                           -0.144381 -0.046529
# lead_time                              0.000149 -0.012640
# arrival_date_year                      0.030872  0.056463
# arrival_date_week_number               0.005508 -0.018244
# arrival_date_day_of_month              0.010613  0.000202
# stays_in_weekend_nights                0.063281  0.161427
# stays_in_week_nights                   0.096209  0.195135
# adults                                -0.051673  0.024994
# children                               0.048952  0.050581
# babies                                 0.083440  0.030266
# is_repeated_guest                      0.012092 -0.052264
# previous_cancellations                -0.026993 -0.018192
# previous_bookings_not_canceled         0.011608 -0.046296
# booking_changes                        1.000000  0.036478
# agent                                  0.036478  1.000000
# days_in_waiting_list                  -0.011634 -0.040853
# adr                                    0.019618  0.016707
# required_car_parking_spaces            0.065620  0.119158
# total_of_special_requests              0.052833  0.060696
# arrival_date_month_num                 0.004809 -0.017179
# hotel_encode                          -0.072820 -0.651043
#
#                                 days_in_waiting_list       adr  \
# is_canceled                                 0.054186  0.047557
# lead_time                                   0.170084 -0.063077
# arrival_date_year                          -0.056497  0.197580
# arrival_date_week_number                    0.022933  0.075791
# arrival_date_day_of_month                   0.022728  0.030245
# stays_in_weekend_nights                    -0.054151  0.049342
# stays_in_week_nights                       -0.002020  0.065237
# adults                                     -0.008283  0.230641
# children                                   -0.033271  0.324853
# babies                                     -0.010621  0.029186
# is_repeated_guest                          -0.022235 -0.134314
# previous_cancellations                      0.005929 -0.065646
# previous_bookings_not_canceled             -0.009397 -0.072144
# booking_changes                            -0.011634  0.019618
# agent                                      -0.040853  0.016707
# days_in_waiting_list                        1.000000 -0.040756
# adr                                        -0.040756  1.000000
# required_car_parking_spaces                -0.030600  0.056628
# total_of_special_requests                  -0.082730  0.172185
# arrival_date_month_num                      0.019045  0.079315
# hotel_encode                                0.072432  0.096719
#
#                                 required_car_parking_spaces  \
# is_canceled                                       -0.195498
# lead_time                                         -0.116451
# arrival_date_year                                 -0.013684
# arrival_date_week_number                           0.001920
# arrival_date_day_of_month                          0.008683
# stays_in_weekend_nights                           -0.018554
# stays_in_week_nights                              -0.024859
# adults                                             0.014785
# children                                           0.056255
# babies                                             0.037383
# is_repeated_guest                                  0.077090
# previous_cancellations                            -0.018492
# previous_bookings_not_canceled                     0.047653
# booking_changes                                    0.065620
# agent                                              0.119158
# days_in_waiting_list                              -0.030600
# adr                                                0.056628
# required_car_parking_spaces                        1.000000
# total_of_special_requests                          0.082626
# arrival_date_month_num                             0.000257
# hotel_encode                                      -0.218873
#
#                                 total_of_special_requests  \
# is_canceled                                     -0.234658
# lead_time                                       -0.095712
# arrival_date_year                                0.108531
# arrival_date_week_number                         0.026149
# arrival_date_day_of_month                        0.003062
# stays_in_weekend_nights                          0.072671
# stays_in_week_nights                             0.068192
# adults                                           0.122884
# children                                         0.081736
# babies                                           0.097889
# is_repeated_guest                                0.013050
# previous_cancellations                          -0.048384
# previous_bookings_not_canceled                   0.037824
# booking_changes                                  0.052833
# agent                                            0.060696
# days_in_waiting_list                            -0.082730
# adr                                              0.172185
# required_car_parking_spaces                      0.082626
# total_of_special_requests                        1.000000
# arrival_date_month_num                           0.028026
# hotel_encode                                    -0.043390
#
#                                 arrival_date_month_num  hotel_encode
# is_canceled                                   0.011022      0.136531
# lead_time                                     0.131424      0.075381
# arrival_date_year                            -0.527739      0.035267
# arrival_date_week_number                      0.995105      0.001270
# arrival_date_day_of_month                    -0.026063     -0.001862
# stays_in_weekend_nights                       0.018440     -0.186596
# stays_in_week_nights                          0.019212     -0.234020
# adults                                        0.028534     -0.013183
# children                                      0.005437     -0.044210
# babies                                        0.010172     -0.043434
# is_repeated_guest                            -0.030729     -0.050421
# previous_cancellations                        0.037479     -0.012292
# previous_bookings_not_canceled               -0.021640     -0.004441
# booking_changes                               0.004809     -0.072820
# agent                                        -0.017179     -0.651043
# days_in_waiting_list                          0.019045      0.072432
# adr                                           0.079315      0.096719
# required_car_parking_spaces                   0.000257     -0.218873
# total_of_special_requests                     0.028026     -0.043390
# arrival_date_month_num                        1.000000      0.001817
# hotel_encode                                  0.001817      1.000000

# %%
# 삼각형 마스크를 만든다(위 쪽 삼각형에 True, 아래 삼각형에 False)
mask = np.zeros_like(df.corr(), dtype = np.bool)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(15,15))
sns.heatmap(data = df.corr(), annot=True, fmt = '.2f', linewidths=.5, cmap='Blues', 
            mask=mask, cbar_kws={"shrink": .5}, vmin = -1,vmax = 1)

# %%
df.corr()['is_canceled'].abs().sort_values(ascending=False)[1:]
# Out:
# lead_time                         0.293123
# total_of_special_requests         0.234658
# required_car_parking_spaces       0.195498
# booking_changes                   0.144381
# hotel_encode                      0.136531
# previous_cancellations            0.110133
# is_repeated_guest                 0.084793
# adults                            0.060017
# previous_bookings_not_canceled    0.057358
# days_in_waiting_list              0.054186
# adr                               0.047557
# agent                             0.046529
# babies                            0.032491
# stays_in_week_nights              0.024765
# arrival_date_year                 0.016660
# arrival_date_month_num            0.011022
# arrival_date_week_number          0.008148
# arrival_date_day_of_month         0.006130
# children                          0.005036
# stays_in_weekend_nights           0.001791
# Name: is_canceled, dtype: float64

# %%
import scipy.stats as stats

# t-검정
# result = stats.ttest_ind(df['is_canceled'], df['lead_time'])
# result

# %%
# chi-sqare 검정
# for col in df:
#     result = stats.chisquare(df['is_canceled'], df[col])
#     print(result)

# %% [markdown]
# ### 피처

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date',
#        'arrival_date_month_num', 'hotel_encode'],
#       dtype='object')

# %%
# 명목형 변수
object = ['hotel',
        'arrival_date_year',
        'arrival_date_month_num',
        'arrival_date_week_number',
        'arrival_date_day_of_month',
        'stays_in_weekend_nights',
        'stays_in_week_nights',
        'adults',
        'children',
        'babies',
        'meal', # 
        'country', #
        'market_segment', #
        'distribution_channel', #
        'reserved_room_type', #
        'is_repeated_guest', #
        'previous_cancellations',
        'previous_bookings_not_canceled', 
        'reserved_room_type', #
        'assigned_room_type', #
        'deposit_type', #
        'agent', 
        'days_in_waiting_list', 
        'customer_type', #
        'required_car_parking_spaces',
        'total_of_special_requests', 
        'reservation_status', 
#        'reservation_status_date',
        'reservation_status_year',
        'reservation_status_month',
        'reservation_status_day'
         ]

# %%
col_lst = df.select_dtypes('object').columns.to_list()
col_lst.pop(1)
# Out:
# 'arrival_date_month'

# %%
for i in range(len(col_lst)):
    df[col_lst[i]+'_encode'] = pd.factorize(df[col_lst[i]])[0]

# %%
# float을 int로 변경
df['children'] = df['children'].astype(int)
df['agent'] = df['agent'].astype(int)

# %%
# 
df['reservation_status_year'] = df['reservation_status_date'].str.split('-').str.get(0).astype(int)
df['reservation_status_month'] = df['reservation_status_date'].str.split('-').str.get(1).astype(int)
df['reservation_status_day'] = df['reservation_status_date'].str.split('-').str.get(2).astype(int)

# %%
df[object].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   arrival_date_year               119390 non-null  int64
#  2   arrival_date_month_num          119390 non-null  int32
#  3   arrival_date_week_number        119390 non-null  int64
#  4   arrival_date_day_of_month       119390 non-null  int64
#  5   stays_in_weekend_nights         119390 non-null  int64
#  6   stays_in_week_nights            119390 non-null  int64
#  7   adults                          119390 non-null  int64
#  8   children                        119390 non-null  int32
#  9   babies                          119390 non-null  int64
#  10  meal                            119390 non-null  object
#  11  country                         119390 non-null  object
#  12  market_segment                  119390 non-null  object
#  13  distribution_channel            119390 non-null  object
#  14  reserved_room_type              119390 non-null  object
#  15  is_repeated_guest               119390 non-null  int64
#  16  previous_cancellations          119390 non-null  int64
#  17  previous_bookings_not_canceled  119390 non-null  int64
#  18  reserved_room_type              119390 non-null  object
#  19  assigned_room_type              119390 non-null  object
#  20  deposit_type                    119390 non-null  object
#  21  agent                           119390 non-null  int32
#  22  days_in_waiting_list            119390 non-null  int64
#  23  customer_type                   119390 non-null  object
#  24  required_car_parking_spaces     119390 non-null  int64
#  25  total_of_special_requests       119390 non-null  int64
#  26  reservation_status              119390 non-null  object
#  27  reservation_status_year         119390 non-null  int32
#  28  reservation_status_month        119390 non-null  int32
#  29  reservation_status_day          119390 non-null  int32
# dtypes: int32(6), int64(13), object(11)
# memory usage: 24.6+ MB

# %%
feature_names = ['hotel',
                'arrival_date_year',
                'arrival_date_month_num',
                'arrival_date_week_number',
                'arrival_date_day_of_month',
                'stays_in_weekend_nights',
                'stays_in_week_nights',
                'adults',
                'children',
                'babies',
                'meal', #
                'country', #
                'market_segment', #
                'distribution_channel', #
                'reserved_room_type', #
                'is_repeated_guest', #
                'previous_cancellations',
                'previous_bookings_not_canceled', 
                'reserved_room_type', #
                'assigned_room_type', #
                'deposit_type', #
                'agent', 
                'days_in_waiting_list', 
                'customer_type', #
                'required_car_parking_spaces',
                'total_of_special_requests', 
                'reservation_status', 
                'reservation_status_year',
                'reservation_status_month',
                'reservation_status_day' ]

# %%
label_name = 'is_canceled'
label_name
# Out:
# 'is_canceled'

# %%
df_num = df.drop(df.select_dtypes('object').columns,axis=1)

# %%
Y = df[label_name]

# %%
X = df_num.drop(label_name,axis=1)

# %%
kf = KFold(n_splits=5,random_state=42)

# %%
model = RandomForestClassifier(random_state=42)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-f6bc4bea18a0> in <module>
# ----> 1 model = RandomForestClassifier(random_state=42,cv=kf)
#
# TypeError: __init__() got an unexpected keyword argument 'cv'

# %%
results = cross_val_score(model,X_train,y_train,cv=kf,scoring='f1')

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
predictions = model.predict(X_test)

# %%
f1_score(y_test,predictions)
# Out:
# 1.0

# %%
confusion_matrix(y_test,predictions)
# Out:
# array([[14907,     0],
#        [    0,  8971]], dtype=int64)

# %%
y_test
# Out:
# 30946     0
# 40207     1
# 103708    0
# 85144     0
# 109991    0
#          ..
# 48376     1
# 19712     0
# 32188     0
# 92983     0
# 50036     1
# Name: is_canceled, Length: 23878, dtype: int64

# %%
df['is_canceled'].value_counts()
# Out:
# 0    75166
# 1    44224
# Name: is_canceled, dtype: int64

# %%
y_train.value_counts()
# Out:
# 0    60259
# 1    35253
# Name: is_canceled, dtype: int64

# %%
35253 / 44224
# Out:
# 0.7971463458755427

# %%
y_test.value_counts()
# Out:
# 0    14907
# 1     8971
# Name: is_canceled, dtype: int64

# %%
8971 / 44224
# Out:
# 0.2028536541244573

# %% [markdown]
# ### 학습, 예측 데이터셋 만들기

# %% [markdown]
# ### StandardScaler 로 데이터 스케일 맞추기

# %%
# from sklearn.preprocessing import StandardScaler

# X_ = StandardScaler().fit(X).transform(X)
# X_

# %%
# 스케일링이 잘 되었는지 히스토그램으로 확인

# h = pd.DataFrame(X).hist(figsize=(15, 15))

# %% [markdown]
# ### 학습세트와 테스트세트 만들기

# %%
# model_selection을 통해 데이터를 나눕니다.

from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(X_, y, test_size=0.2, random_state=42) 
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2,random_state = 42)

# %%
print(X_train.shape)
X_train[:1]

# %%
print(X_test.shape)
X_test[:1]
