# %% [markdown]
# # 호텔 예약 취소 예측

# %% [markdown]
# ## 서론

# %% [markdown]
# ### 분석 배경

# %% [markdown]
# 호텔 방을 예약하기에 가장 좋은 시기가 언제인지 궁금한 적이 있습니까?
# 아니면 최고의 일일 요금을 얻기 위해 최적의 체류 기간?
# 호텔이 불균형 적으로 많은 수의 특별 요청을 받을 가능성이 있는지 여부를 예측하려면 어떻게 해야 합니까?
#
# 이 호텔 예약 데이터 세트는 이러한 질문을 탐색하는 데 도움이 됩니다!
#
# 데이터에서 다루는 주제 및 질문 :
#
# 손님은 어디에서 오나요?<br>
# 객실당 1 박 요금은 얼마입니까?<br>
# 1 박 가격은 연중 어떻게 달라 집니까?<br>
# 가장 바쁜 달은 어느 것입니까?<br>
# 사람들이 호텔에 얼마나 오래 있습니까?<br>
# 시장 세그먼트 별 예약<br>
# 몇 번의 예약이 취소 되었습니까?<br>
# 어느 달에 가장 많은 취소 횟수가 있습니까?<br>
# 취소를 예측하는 데 가장 중요한 기능은 무엇입니까?

# %% [markdown]
# ### 분석 목표

# %% [markdown]
# 호텔 취소 예측

# %% [markdown]
# ### 변수 설명

# %% [markdown]
#  이름 | 형식 | 설명
# :---:|:---:|:---
# 호텔 |  | 호텔 구분,<br> H1 = 리조트 호텔,<br> H2 = 시티 호텔
# is_canceled |  | 예약이 취소되었는지 여부를 나타내는 값,<br> 0:숙박,<br> 1:취소
# lead_time |  | 예약 시작 날짜와 도착 날짜 사이에 경과 된 일수
# arrival_date_year |  | 도착 연도
# arrival_date_month |  | 도착 월
# arrival_date_week_number |  | 도착한 주
# arrival_date_day_of_month |  | 도착한 일자
# stays_in_weekend_nights |  | 손님이 호텔에 숙박하거나 예약한 주말 밤(토요일 또는 일요일)의 수
# stays_in_week_nights |  | 손님이 호텔에 숙박하거나 예약한 주중 밤(월요일 ~ 금요일)의 수
# adults |  | 성인의 수
# children |  | 어린이의 수
# babies |  | 아기의 수
# meal |  | 예약 된 식사 유형,<br> Undefined/SC : 식사 패키지 없음,<br> BB : 침대&아침 식사,<br> HB : 하프 보드 (아침 식사와 다른 식사 – 보통 저녁),<br> FB : 풀 보드 (아침, 점심 및 저녁)
# country |  | ISO에서 규정한 ISO 3166-1 국가코드 표준 형식으로 표기
# market_segment |  | TA : 여행사,<br> TO : 관광업자
# distribution_channel |  | 예약 배포 채널,<br> TA : 여행사,<br> TO : 관광업자
# is_repeated_guest |  | 예약 이름이 반복 손님의 이름인지 (1) 아닌지 (0)를 나타내는 값
# previous_cancellations |  | 현재 예약 이전에 고객이 취소 한 이전 예약 수
# previous_bookings_not_canceled |  | 현재 예약 이전에 고객이 취소하지 않은 이전 예약 수
# reserved_room_type |  | 예약된 객실 유형의 코드
# assigned_room_type |  | 예약에 지정된 객실 유형 코드. 호텔 운영상의 이유(예 : 초과 예약) 또는 고객 요청으로 인해 <br>지정된 객실 유형이 예약 된 객실 유형과 다를 수 있음
# booking_changes |  | PMS에 예약을 입력 한 순간부터 체크인 또는 취소까지 예약에 대한 변경 / 수정 횟수
# deposit_type |  | 고객이 예약을 보장하기 위해 보증금을 지불했는지 표시,<br> No Deposit : 보증금 없음 ,<br> Non Refund : 총 체류 기간에 대한 가치 == 보증금, 환불 불가,<br> Refundable : 총 체류 기간에 대한 가치 > 보증금 , 환불 가능
# agent |  | 예약을 하거나 예약 요금을 지불한 회사
# company |  | 예약 또는 지불 책임이 있는 회사/법인
# days_in_waiting_list |  | 예약이 고객에게 확인되기 전 대기 목록에 있었던 일 수
# customer_type |  | Transient : 그외 채널로 호텔 객실을 예약하는 개별 고객,<br> Contract : 항공사 크루나 장기 투숙고객 등,<br> Transient-Party : 써드파티 채널을 통해 호텔 객실을 예약하는 개별 고객,<br> Group : 보통 10개 이상의 객실을 한꺼번에 이용하는 고객
# adr |  | 모든 숙박 거래의 총계를 총 숙박 일수로 나누어 정의한 평균 일일 요금
# required_car_parking_spaces |  | 고객이 요구 한 주차 공간 수
# total_of_special_requests |  | 고객이 요청한 특별 요구사항 수 (예 : 트윈 베드 또는 고층)
# reservation_status |  | 다음 세 가지 범주 중 하나를 가정하여 예약 마지막 상태,<br> Canceled : 예약 취소,<br> Check-Out : 고객이 체크인했지만 이미 출발함,<br> No-Show : 고객은 체크인을 하지 않고 호텔에 그 이유를 알림
# reservation_status_date |  | 마지막 상태가 설정된 날짜,<br> 이 변수는 ReservationStatus와 함께 사용하여 예약이 언제 취소되었는지 또는 고객이 호텔을 체크 아웃했는지를 알 수 있음

# %% [markdown]
# 출처 : [Hotel booking demand](https://www.kaggle.com/jessemostipak/hotel-booking-demand)

# %% [markdown]
# ## 라이브러리 로드

# %% [markdown]
# #### 필요한 라이브러리 불러오기

# %%
import pandas as pd # 데이터 프레임
import numpy as np # 계산
import re # 정규표현식

import warnings
warnings.filterwarnings('ignore') # warning 메시지 제거

import seaborn as sns # 시각화
import graphviz # 시각화

# %matplotlib inline

# %% [markdown]
# #### 시각화를 위한 한글 폰트 설정하기

# %%
import matplotlib.pyplot as plt

# 한글 폰트 지정
#plt.rc('font', family='AppleGothic') # 맥
plt.rc('font', family='Malgun Gothic') # 윈도우

# 마이너스 값 깨지는 현상 해결
plt.rc('axes', unicode_minus=False)

# 레티나 디스플레이 설정
from IPython.display import set_matplotlib_formats

set_matplotlib_formats('retina')

# %% [markdown]
# #### 작업 경로 지정

# %%
import os # wd 변경

# os로 작업 경로 지정
# os.chdir('D:/5 Project/GitHub/CollaborationWork/jyeon94/Learning_Spoons_Second_Project/data/')
os.chdir('/Users/jungdayoung/Documents/GitHub/Learning_Spoons_Third_Project/data/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-238b8c83e900> in <module>
#       3 # os로 작업 경로 지정
#       4 # os.chdir('D:/5 Project/GitHub/CollaborationWork/jyeon94/Learning_Spoons_Second_Project/data/')
# ----> 5 os.chdir('/Users/jungdayoung/Documents/GitHub/Learning_Spoons_Third_Project/data/')
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: '/Users/jungdayoung/Documents/GitHub/Learning_Spoons_Third_Project/data/'

# %% [markdown]
# ## 데이터셋 가져오기

# %%
df = pd.read_csv('../data/hotel_bookings.csv')
df.shape
# Out:
# (119390, 32)

# %%
# 컬럼이 모두 보이도록 설정합니다.

pd.options.display.max_columns = 32

# %%
# 미리보기를 합니다.

df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %% [markdown]
# ## EDA

# %% [markdown]
# ### pandas-profiling

# %%
# pandas_profiling 을 통해 ProfileReport 로 간단한 eda 리포트를 만들어 봅니다.

# from pandas_profiling import ProfileReport

# Profile = ProfileReport(df)
# Profile.to_file(output_file = 'hotel_cancelations.html')

# %% [markdown]
# ### histogram

# %%
h = df.hist(figsize=(15, 15))

# %% [markdown]
# ### 데이터 전처리

# %% [markdown]
# #### 결측치 채우기

# %%
df.shape
# Out:
# (119390, 35)

# %%
# 결측치 확인
df.isnull().sum().sort_values(ascending=False).head()
# Out:
# company      112593
# agent         16340
# country         488
# children          4
# lead_time         0
# dtype: int64

# %%
# 'country' 값의 결측치를 "None" 으로 채우기
df['country'] = df['country'].fillna("None")

# %%
# 'company'의 결측치가 약 94.3%로 해당 열 삭제
df = df.drop(['company'], axis=1)

# %%
# 'agent'의 결측치를 0으로 대체
df['agent'] = df['agent'].fillna(0)

# %%
# 'children'의 결측치 4개를 0으로 대체
df['children'] = df['children'].fillna(0)

# %% [markdown]
# #### 데이터 타입 변경

# %%
# 'arrival_date_month'의 데이터 타입을 숫자로 변경한 컬럼 추가
import calendar
calendar_month = {v:k for k,v in enumerate(calendar.month_abbr)}
del calendar_month['']
 
def month_number(data):
    for keys,values in calendar_month.items():
        data.loc[data['arrival_date_month'].str.contains(keys),'arrival_date_month_num'] = values
    data['arrival_date_month_num'] = data['arrival_date_month_num'].astype('int')
    return data[['arrival_date_month','arrival_date_month_num']]

# %%
month_number(df)
# Out:
#        arrival_date_month  arrival_date_month_num
# 0                    July                       7
# 1                    July                       7
# 2                    July                       7
# 3                    July                       7
# 4                    July                       7
# ...                   ...                     ...
# 119385             August                       8
# 119386             August                       8
# 119387             August                       8
# 119388             August                       8
# 119389             August                       8
#
# [119390 rows x 2 columns]

# %%
df[['is_canceled','agent']] = df[['is_canceled','agent']].astype('str')

# %%
# 호텔 컬럼을 수치형으로 변환
df['hotel_encode'] = df['hotel'].apply(lambda x: 0 if x == 'Resort Hotel' else 1)
df['hotel_encode'] = df['hotel_encode'].astype(str)

# %%
df['children'] = df['children'].astype(int)

# %%
df[['arrival_date_year','arrival_date_month_num','arrival_date_day_of_month']] = df[['arrival_date_year','arrival_date_month_num','arrival_date_day_of_month']].astype('str')

# %%
df['arrival_date'] = df['arrival_date_year'] + "-" + df['arrival_date_month_num'] + "-" + df['arrival_date_day_of_month']

# %%
df['arrival_date'] = pd.to_datetime(df['arrival_date'])

# %%
df['arrival_day_of_week'] = df['arrival_date'].dt.dayofweek

# %%
# df.to_csv('hotel_canceled.csv', index=False)

# %% [markdown]
# ### 데이터 시각화

# %% [markdown]
# #### 수치형

# %%
numeric_col = df.dtypes[df.dtypes != 'object']
numeric_col = numeric_col.index.to_list()
del numeric_col[1:4]
del numeric_col[6]
del numeric_col[-1]
numeric_col.append('is_canceled')

# %%
h2 = df[numeric_col].hist(figsize=(15,15))

# %%
sns.pairplot(df[[ 'stays_in_week_nights', 'adults', 'children', 'babies',
                 'is_canceled','days_in_waiting_list','adr','total_of_special_requests']], 
             hue = 'is_canceled', diag_kws={'bw':5})

# %%
sns.pairplot(df[['lead_time','is_canceled']],hue='is_canceled',height=5)

# %%
parking_spaces = list(df['required_car_parking_spaces'].unique())
for i in parking_spaces:
    globals()['df_{}'.format(i)] = df[df['required_car_parking_spaces']==i]
    print(i)
# Out:
# 0
# 1
# 2
# 8
# 3

# %%
range_length = list(range(1,5))
# Out:
# [1, 2, 3, 4]

# %%
ffig, axes = plt.subplots(nrows = 1, ncols = 5, figsize = (20,5))
figure.set_size_inches(15,5)
for i,j in enumerate(parking_spaces):
     sns.countplot(data= globals()['df_{}'.format(j)] ,x='required_car_parking_spaces',hue='is_canceled',ax=axes[i])
#     sns.countplot(data=df_1,x='required_car_parking_spaces',hue='is_canceled',ax=ax2)
#     sns.countplot(data=df_2,x='required_car_parking_spaces',hue='is_canceled',ax=ax3)
#     sns.countplot(data=df_8,x='required_car_parking_spaces',hue='is_canceled',ax=ax4)
#     sns.countplot(data=df_3,x='required_car_parking_spaces',hue='is_canceled',ax=ax5
     print(i,j)
# Out:
# 0 0
# 1 1
# 2 2
# 3 8
# 4 3

# %%
df[numeric_col].corr()
# Out:
#                              lead_time    adults  children    babies  \
# lead_time                     1.000000  0.119519 -0.037613 -0.020915
# adults                        0.119519  1.000000  0.030440  0.018146
# children                     -0.037613  0.030440  1.000000  0.024030
# babies                       -0.020915  0.018146  0.024030  1.000000
# is_repeated_guest            -0.124410 -0.146426 -0.032858 -0.008943
# previous_cancellations        0.086042 -0.006738 -0.024729 -0.007501
# booking_changes               0.000149 -0.051673  0.048952  0.083440
# days_in_waiting_list          0.170084 -0.008283 -0.033271 -0.010621
# adr                          -0.063077  0.230641  0.324853  0.029186
# required_car_parking_spaces  -0.116451  0.014785  0.056255  0.037383
# total_of_special_requests    -0.095712  0.122884  0.081736  0.097889
#
#                              is_repeated_guest  previous_cancellations  \
# ...

# %%
# 삼각형 마스크를 만든다(위 쪽 삼각형에 True, 아래 삼각형에 False)
mask = np.zeros_like(df[numeric_col].corr(), dtype = np.bool)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(15,15))
sns.heatmap(data = df[numeric_col].corr(), annot=True, fmt = '.2f', linewidths=.5, cmap='Blues', 
            mask=mask, cbar_kws={"shrink": .5}, vmin = -1,vmax = 1)

# %%
# df_0 = df.loc[df['is_canceled']=='0',['lead_time','adr','days_in_waiting_list','total_of_special_requests']].copy()
# df_1 = df.loc[df['is_canceled']=='1',['lead_time','adr','days_in_waiting_list','total_of_special_requests']].copy()

df_0 = df.loc[df['is_canceled']=='0',numeric_col].copy()
df_1 = df.loc[df['is_canceled']=='1',numeric_col].copy()

# %%
import scipy.stats as stats
lresult_stat = []
lresult_pvalue = []
t_stat = []
t_pvalue = []

def t_test(x,y):   
    lresult=stats.levene(x,y)
    lresult_stat.append(lresult.statistic)
    lresult_pvalue.append(lresult.pvalue)
    if round(lresult.pvalue,2) < 0.05:
        result = stats.ttest_ind(x,y,equal_var=False)
    else:
        result = stats.ttest_ind(x,y,equal_var=True)
    t_stat.append(round(result.statistic,2))
    t_pvalue.append(round(result.pvalue,2))
    return lresult_stat, lresult_pvalue, t_stat, t_pvalue

# %%
for i in numeric_col:
    t_test(df_0[i],df_1[i])

# %%
t_test_result = pd.DataFrame({'column':numeric_col,'등분산_통계량':lresult_stat,'등분산_유의확률':lresult_pvalue,
              't-test_통계량':t_stat,'t-test_유의확률':t_pvalue})

# %%
t_test_result[(t_test_result['t-test_유의확률'])>0.05]
# Out:
#                     column    등분산_통계량  등분산_유의확률  t-test_통계량  t-test_유의확률
# 1  stays_in_weekend_nights  14.007020  0.000182        0.62         0.54
# 4                 children   3.028218  0.081830       -1.74         0.08

# %% [markdown]
# #### 명목형

# %%
categorical_features = ['meal', 'market_segment', 'distribution_channel']
fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (20,5)) # 빈서브플롯


for i, col_name in enumerate(categorical_features):
    col = i
    sns.countplot(data=df, x = col_name, hue = 'is_canceled', ax = axes[i])

# %%
plt.figure(figsize=(10,5))
g = sns.barplot(data=df,x='arrival_day_of_week',y='arrival_day_of_week',estimator=lambda x: len(x) / len(df),hue='is_canceled')
g.set(xticklabels=['월','화','수','목','금','토','일'])
g.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
plt.figure(figsize = (20,7))
plt.xticks(rotation=90)
sns.countplot(data=df, x = 'country', hue = 'is_canceled',order=df.country.value_counts(ascending=False).iloc[:10].index)

# %%
sns.pairplot(df[['agent','is_canceled']],hue='is_canceled',height=5)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date',
#        'arrival_date_month_num', 'hotel_encode'],
#       dtype='object')

# %%
object_col = df.dtypes[df.dtypes == 'object']
object_col = object_col.index.to_list()
object_col.extend(('arrival_date_month', 'arrival_date_week_number',
       'arrival_date_day_of_month','arrival_date_month_num'))

# %%
del object_col[1]

# %%
for i in object_col:
    df_cr = pd.crosstab(df['is_canceled'],df[i])
    print(df_cr)
    print(" ")
    plot = sns.distplot(df_cr,ax= )
    print("-"*100)
# Out:
# hotel        City Hotel  Resort Hotel
# is_canceled
# 0                 46228         28938
# 1                 33102         11122
#
# ----------------------------------------------------------------------------------------------------
# arrival_date_month  April  August  December  February  January  July  June  \
# is_canceled
# 0                    6565    8638      4409      5372     4122  7919  6404
# 1                    4524    5239      2371      2696     1807  4742  4535
#
# arrival_date_month  March   May  November  October  September
# is_canceled
# 0                    6645  7114      4672     6914       6392
# 1                    3149  4677      2122     4246       4116
#
# ----------------------------------------------------------------------------------------------------
# meal            BB   FB    HB    SC  Undefined
# is_canceled
# 0            57800  320  9479  6684        883
# 1            34510  478  4984  3966        286
#
# ...

# %%
df_cr = pd.crosstab(df['is_canceled'], df['hotel'])
print(df_cr)
sns.distplot(df_cr)
# Out:
# hotel        City Hotel  Resort Hotel
# is_canceled
# 0                 46228         28938
# 1                 33102         11122

# %%
df_cr = pd.crosstab(df['is_canceled'], df['arrival_date_month'])
print(df_cr)
sns.distplot(df_cr)
# Out:
# arrival_date_month  April  August  December  February  January  July  June  \
# is_canceled
# 0                    6565    8638      4409      5372     4122  7919  6404
# 1                    4524    5239      2371      2696     1807  4742  4535
#
# arrival_date_month  March   May  November  October  September
# is_canceled
# 0                    6645  7114      4672     6914       6392
# 1                    3149  4677      2122     4246       4116

# %%
df_cr = pd.crosstab(df['is_canceled'], df['meal'])
print(df_cr)
sns.distplot(df_cr)
# Out:
# meal            BB   FB    HB    SC  Undefined
# is_canceled
# 0            57800  320  9479  6684        883
# 1            34510  478  4984  3966        286

# %%
df_cr = pd.crosstab(df['is_canceled'], df['country'])
print(df_cr)
sns.distplot(df_cr)
# Out:
# country      ABW  AGO  AIA  ALB  AND  ARE  ARG  ARM  ASM  ATA  ATF  AUS   AUT  \
# is_canceled
# 0              2  157    1   10    2    8  160    6    1    2    1  319  1033
# 1              0  205    0    2    5   43   54    2    0    0    0  107   230
#
# country      AZE  BDI   BEL  ...  TUN  TUR  TWN  TZA  UGA  UKR  UMI  URY  \
# is_canceled                  ...
# 0              8    1  1868  ...   20  146   37    2    2   48    0   23
# 1              9    0   474  ...   19  102   14    3    0   20    1    9
#
# country       USA  UZB  VEN  VGB  VNM  ZAF  ZMB  ZWE
# is_canceled
# 0            1596    2   14    0    6   49    1    2
# 1             501    2   12    1    2   31    1    2
#
# [2 rows x 178 columns]

# %%
df_cr = pd.crosstab(df['is_canceled'], df['market_segment'])
print(df_cr)
sns.distplot(df_cr)
# Out:
# market_segment  Aviation  Complementary  Corporate  Direct  Groups  \
# is_canceled
# 0                    185            646       4303   10672    7714
# 1                     52             97        992    1934   12097
#
# market_segment  Offline TA/TO  Online TA  Undefined
# is_canceled
# 0                       15908      35738          0
# 1                        8311      20739          2

# %%
df_cr = pd.crosstab(df['is_canceled'], df['distribution_channel'])
print(df_cr)
sns.distplot(df_cr)
# Out:
# distribution_channel  Corporate  Direct  GDS  TA/TO  Undefined
# is_canceled
# 0                          5203   12088  156  57718          1
# 1                          1474    2557   37  40152          4

# %%
df_cr = pd.crosstab(df['is_canceled'], df['assigned_room_type'])
print(df_cr)
sns.distplot(df_cr)
# Out:
# assigned_room_type      A     B     C      D     E     F     G    H    I    K  \
# is_canceled
# 0                   41105  1651  1929  18960  5838  2824  1773  461  358  267
# 1                   32948   512   446   6362  1968   927   780  251    5   12
#
# assigned_room_type  L   P
# is_canceled
# 0                   0   0
# 1                   1  12

# %%
df_cr = pd.crosstab(df['is_canceled'], df['deposit_type'])
print(df_cr)
sns.distplot(df_cr)
# Out:
# deposit_type  No Deposit  Non Refund  Refundable
# is_canceled
# 0                  74947          93         126
# 1                  29694       14494          36

# %%
df_cr = pd.crosstab(df['is_canceled'], df['agent'])
# print(df_cr)
sns.distplot(df_cr)

# %%
df_cr = pd.crosstab(df['is_canceled'], df['customer_type'])
print(df_cr)
sns.distplot(df_cr)
# Out:
# customer_type  Contract  Group  Transient  Transient-Party
# is_canceled
# 0                  2814    518      53099            18735
# 1                  1262     59      36514             6389

# %%
df_cr = pd.crosstab(df['is_canceled'], df['reservation_status'])
print(df_cr)
sns.distplot(df_cr)
# Out:
# reservation_status  Canceled  Check-Out  No-Show
# is_canceled
# 0                          0      75166        0
# 1                      43017          0     1207

# %%
df_cr = pd.crosstab(df['is_canceled'], df['reservation_status_date'])
# print(df_cr)
sns.distplot(df_cr)

# %%
lst = object_col

# %%
import scipy.stats as stats

def chi(y,x='is_canceled'):
    df_cr = pd.crosstab(df[x],df[y])
    chi2, p , dof, ex = stats.chi2_contingency(df_cr,correction=False)
    print(x,y,p)

# %%
for i in lst:
    chi(i)
# Out:
# is_canceled hotel 0.0
# is_canceled is_canceled 0.0
# is_canceled arrival_date_month 3.6718226093273626e-119
# is_canceled meal 1.3212351959124216e-64
# is_canceled country 0.0
# is_canceled market_segment 0.0
# is_canceled distribution_channel 0.0
# is_canceled reserved_room_type 1.121956218424043e-133
# is_canceled assigned_room_type 0.0
# is_canceled deposit_type 0.0
# is_canceled agent 0.0
# is_canceled customer_type 0.0
# is_canceled reservation_status 0.0
# is_canceled reservation_status_date 0.0
# is_canceled hotel_encode 0.0

# %%
df_1 = df.copy()

# %%
col_lst = df_1.select_dtypes('object').columns.to_list()
col_lst.pop(1)
# Out:
# 'is_canceled'

# %%
for i in range(len(col_lst)):
    df_1[col_lst[i]+'_encode'] = pd.factorize(df_1[col_lst[i]])[0]

# %%
# 
# df_1['reservation_status_year'] = df_1['reservation_status_date'].str.split('-').str.get(0).astype(int)
# df_1['reservation_status_month'] = df_1['reservation_status_date'].str.split('-').str.get(1).astype(int)
# df_1['reservation_status_day'] = df_1['reservation_status_date'].str.split('-').str.get(2).astype(int)

# %%
df_1.head()
# Out:
#           hotel is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel           0        342               2015               July
# 1  Resort Hotel           0        737               2015               July
# 2  Resort Hotel           0          7               2015               July
# 3  Resort Hotel           0         13               2015               July
# 4  Resort Hotel           0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2         0       0
# ...

# %% [markdown]
# ### PCA

# %% [markdown]
# ### 피처

# %%
df_1.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date',
#        'arrival_date_month_num', 'hotel_encode', 'arrival_date_month_encode',
#        'meal_encode', 'country_encode', 'market_segment_encode',
#        'distribution_channel_encode', 'reserved_room_type_encode',
#        'assigned_room_type_encode', 'deposit_type_encode', 'agent_encode',
# ...

# %%
df_1[numeric_col].columns
# Out:
# Index(['lead_time', 'arrival_date_year', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'booking_changes',
#        'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
#        'total_of_special_requests', 'arrival_date_month_num'],
#       dtype='object')

# %%
feature_names = ['lead_time', 'arrival_date_year', 'arrival_date_week_number',
                 'stays_in_weekend_nights',
                 'stays_in_week_nights', #'adults', 'children', 'babies', 'is_repeated_guest', 
                 'previous_cancellations',
                 'previous_bookings_not_canceled', 'booking_changes', #'days_in_waiting_list', 
                 'adr', 'required_car_parking_spaces',
                 'total_of_special_requests', 'arrival_date_month_num',
                 'hotel_encode', 'arrival_date_month_encode',
                 'meal_encode', 'country_encode', 'market_segment_encode',
                 'distribution_channel_encode', 'reserved_room_type_encode',
                 'assigned_room_type_encode', 'deposit_type_encode', 'agent_encode',
                 'customer_type_encode',
                 'reservation_status_date_encode', 'hotel_encode_encode',
                 'reservation_status_year', 'reservation_status_month',
                 'reservation_status_day']

# %%
label_name = 'is_canceled'
label_name
# Out:
# 'is_canceled'

# %%
df_1[feature_names].head()
# Out:
#    lead_time  arrival_date_year  arrival_date_week_number  \
# 0        342               2015                        27
# 1        737               2015                        27
# 2          7               2015                        27
# 3         13               2015                        27
# 4         14               2015                        27
#
#    stays_in_weekend_nights  stays_in_week_nights  previous_cancellations  \
# 0                        0                     0                       0
# 1                        0                     0                       0
# 2                        0                     1                       0
# 3                        0                     1                       0
# 4                        0                     2                       0
#
#    previous_bookings_not_canceled  booking_changes   adr  \
# 0                               0                3   0.0
# 1                               0                4   0.0
# ...

# %%
X = df_1[feature_names]
X.shape
# Out:
# (119390, 28)

# %%
y = df_1[label_name]
y.shape
# Out:
# (119390,)

# %% [markdown]
# ### 학습, 예측 데이터셋 만들기

# %% [markdown]
# ### StandardScaler 로 데이터 스케일 맞추기

# %%
# from sklearn.preprocessing import StandardScaler

# X_ = StandardScaler().fit(X).transform(X)
# X_

# %%
# 스케일링이 잘 되었는지 히스토그램으로 확인

# h = pd.DataFrame(X).hist(figsize=(15, 15))

# %% [markdown]
# ### 학습세트와 테스트세트 만들기

# %%
# model_selection을 통해 데이터를 나눕니다.

from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(X_, y, test_size=0.2, random_state=42) 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print(X_train.shape)
X_train[:1]
# Out:
# (95512, 28)
#         lead_time  arrival_date_year  arrival_date_week_number  \
# 111241         88               2017                        18
#
#         stays_in_weekend_nights  stays_in_week_nights  previous_cancellations  \
# 111241                        1                     2                       0
#
#         previous_bookings_not_canceled  booking_changes    adr  \
# 111241                               0                0  135.0
#
#         required_car_parking_spaces  total_of_special_requests  \
# 111241                            0                          2
#
#         arrival_date_month_num  hotel_encode  arrival_date_month_encode  \
# 111241                       5             1                         10
#
#         meal_encode  country_encode  market_segment_encode  \
# 111241            0               5                      2
#
#         distribution_channel_encode  reserved_room_type_encode  \
# 111241                            2                          2
#
# ...

# %%
print(X_test.shape)
X_test[:1]
# Out:
# (23878, 28)
#         lead_time  arrival_date_year  arrival_date_week_number  \
# 104780         34               2017                         3
#
#         stays_in_weekend_nights  stays_in_week_nights  previous_cancellations  \
# 104780                        0                     2                       0
#
#         previous_bookings_not_canceled  booking_changes     adr  \
# 104780                               0                0  106.75
#
#         required_car_parking_spaces  total_of_special_requests  \
# 104780                            0                          2
#
#         arrival_date_month_num  hotel_encode  arrival_date_month_encode  \
# 104780                       1             1                          6
#
#         meal_encode  country_encode  market_segment_encode  \
# 104780            0              12                      2
#
#         distribution_channel_encode  reserved_room_type_encode  \
# 104780                            2                          1
# ...

# %%
# DecisionTree 를 사용합니다.

# from sklearn.tree import DecisionTreeClassifier

# model = DecisionTreeClassifier()
# model

# %%
# RandomForest 를 사용합니다.

from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=1000,
                              n_jobs=-1,
                              max_depth=8, 
                              random_state=42)
model
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=8, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=-1, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
# 훈련
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=8, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=-1, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
predictions = model.predict(X_test)
len(predictions)
# Out:
# 23878

# %%
y_train.value_counts(normalize=True)
# Out:
# 0    0.630329
# 1    0.369671
# Name: is_canceled, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# 0    0.626602
# 1    0.373398
# Name: is_canceled, dtype: float64

# %%
# 73.0379428762878
# 85.95359745372309
# 86.44777619566128 # cildren, baby 제외
# 86.41846050758019 # is_reapeat 어쩌구, adult 제외
# 86.66136192310914 # day 어쩌구 제외

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, predictions) * 100
# Out:
# 86.66136192310914

# %%
# f1_score 를 계산합니다.

from sklearn.metrics import f1_score

f1_score(y_test, predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-148-d75c625b8be0> in <module>
#       3 from sklearn.metrics import f1_score
#       4
# ----> 5 f1_score(y_test, predictions)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1097                        pos_label=pos_label, average=average,
#    1098                        sample_weight=sample_weight,
# -> 1099                        zero_division=zero_division)
#    1100
#    1101
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1224                                                  warn_for=('f-score',),
# ...

# %%
# 피처의 중요도를 추출하기

mf = model.feature_importances_
mf
# Out:
# array([0.09898614, 0.01163846, 0.02069547, 0.00297124, 0.00534851,
#        0.05870211, 0.00587481, 0.02257312, 0.0157045 , 0.03331336,
#        0.06076581, 0.01763272, 0.00340682, 0.01003347, 0.00209501,
#        0.13449075, 0.06378016, 0.02023907, 0.00396307, 0.01460687,
#        0.23849348, 0.04828883, 0.03645819, 0.02943297, 0.00356031,
#        0.00879247, 0.02492442, 0.00322787])

# %%
# 피처의 중요도 시각화 하기
plt.figure(figsize=(8,7))
sns.barplot(y=feature_names, x=mf)
